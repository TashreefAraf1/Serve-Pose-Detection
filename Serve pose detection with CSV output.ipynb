# %% [markdown]
# <h1>Serve Pose Detection with CSV output and Wrist Rotation</h1>
# <h2>Cell 1: Gets all the libraries needed</h2>
# <h2>Cell 2: Code with csv output without bounding boxes but with arc of racquet</h2>

# %% [markdown]
# Cell 1

# %%
nvidia-smi
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 nvidia-smi
#
# NameError: name 'nvidia' is not defined

# %%
import cv2
import mediapipe as mp
import math
import numpy as np
import torch
import cv2
import mediapipe as mp
import math
import numpy as np
from ultralytics import YOLO

device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cpu

# %% [markdown]
# Cell 2

# %%
import Functions

# Initialize MediaPipe Pose
mp_pose = mp.solutions.pose
pose = mp_pose.Pose(static_image_mode=False, model_complexity=1, enable_segmentation=False, min_detection_confidence=0.5)

# Initialize drawing utilities
mp_drawing = mp.solutions.drawing_utils

# Try to import YOLO models with error handling
yolo_model_racquet = None
yolo_model_ball = None

try:
    from ultralytics import YOLO
    try:
        yolo_model_racquet = YOLO("D:\\DDSA\\YOLO_Models\\yolo11l_best.pt")
        yolo_model_racquet.to('cpu')
    except:
        print("YOLO racquet model not found, using simple detection")
    
    try:
        yolo_model_ball = YOLO("D:\\DDSA\\Serve Pose Detection\\ball_detection_model.pt")
        yolo_model_ball.to('cpu')
    except:
        print("YOLO ball model not found, using simple detection")
        
except ImportError:
    print("Ultralytics YOLO not available, using simple object detection methods")

# Base paths
input_video_dir = 'Your Input Directory'
output_video_dir = 'Your Output Directory'
os.makedirs(output_video_dir, exist_ok=True)

# Video files to process
video_files = ['1.mp4','2.mp4', '3.mp4', '4.mp4', '5.mp4']

# Reference object properties
reference_object_height_px = 100
reference_object_height_cm = 150
conversion_factor = reference_object_height_cm / reference_object_height_px

for video_file in video_files:
    file_name = os.path.splitext(video_file)[0]
    input_video_path = os.path.join(input_video_dir, video_file)
    
    # Open the video file
    cap = cv2.VideoCapture(input_video_path)
    if not cap.isOpened():
        print(f"Error: Could not open video {video_file}")
        continue

    # Get video properties
    frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps = int(cap.get(cv2.CAP_PROP_FPS))

    # Output video setup
    output_video_path = os.path.join(output_video_dir, f'{file_name}_output_video.mp4')
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    out = cv2.VideoWriter(output_video_path, fourcc, fps, (frame_width, frame_height))

    # Create CSV file
    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    csv_filename = os.path.join(output_video_dir, f'{file_name}_analysis_{timestamp}.csv')

    # Initialize variables for this video
    prev_wrist_position = None
    prev_elbow_position = None
    ball_release_time = None
    racquet_contact_time = None
    service_motion_time = None
    current_ball_height_cm = 0
    max_ball_height_cm = 0
    ball_ankle_height_cm = 0
    
    # Wrist arc tracking variables
    wrist_positions = []
    max_wrist_positions = 100
    serving_phase = False
    arc_curvature = 0
    max_arc_curvature = 0
    
    # Wrist rotation tracking variables
    wrist_angle_differences = []
    max_angular_velocity = 0
    current_angular_velocity = 0
    wrist_rotation_angle = 0

    with open(csv_filename, mode='w', newline='') as csv_file:
        csv_writer = csv.writer(csv_file)
        
        # Write CSV header
        header = ['frame_number', 'timestamp_ms']
        
        # Pose landmarks
        for landmark in mp_pose.PoseLandmark:
            header.extend([f'{landmark.name}_x', f'{landmark.name}_y', f'{landmark.name}_z', f'{landmark.name}_visibility'])
        
        # Ball and racquet positions
        header.extend(['ball_x', 'ball_y', 'ball_confidence', 'racquet_x', 'racquet_y', 'racquet_confidence'])
        
        # Calculated metrics
        header.extend([
            'upper_body_tilt', 'arm_angle', 'elbow_flexion', 'wrist_flexion', 
            'left_knee_flexion', 'right_knee_flexion', 'current_ball_height_cm',
            'max_ball_height_cm', 'ball_ankle_height_cm', 'ball_projection_angle',
            'lower_body_tilt', 'trunk_tilt', 'arm_speed', 'service_motion_time',
            'ball_release_time', 'racquet_contact_time', 'wrist_arc_curvature',
            'wrist_rotation_angle', 'wrist_angular_velocity'
        ])
        
        csv_writer.writerow(header)

        while cap.isOpened():
            ret, frame = cap.read()
            if not ret:
                break

            frame_number = int(cap.get(cv2.CAP_PROP_POS_FRAMES))
            timestamp_ms = cap.get(cv2.CAP_PROP_POS_MSEC)
            
            # Initialize row data
            row_data = [frame_number, timestamp_ms]
            landmark_data = [None] * (33 * 4)
            ball_data = [None, None, None]
            racquet_data = [None, None, None]
            calculated_metrics = [None] * 19
            
            # Process frame
            image_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            results_pose = pose.process(image_rgb)

            # Process pose landmarks
            if results_pose.pose_landmarks:
                for i, landmark in enumerate(results_pose.pose_landmarks.landmark):
                    landmark_data[i*4] = landmark.x * frame_width
                    landmark_data[i*4+1] = landmark.y * frame_height
                    landmark_data[i*4+2] = landmark.z
                    landmark_data[i*4+3] = landmark.visibility
                
                mp_drawing.draw_landmarks(frame, results_pose.pose_landmarks, mp_pose.POSE_CONNECTIONS)
                
                # Get keypoints
                landmarks = results_pose.pose_landmarks.landmark
                shoulder_left = landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER]
                shoulder_right = landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER]
                elbow_left = landmarks[mp_pose.PoseLandmark.LEFT_ELBOW]
                elbow_right = landmarks[mp_pose.PoseLandmark.RIGHT_ELBOW]
                wrist_left = landmarks[mp_pose.PoseLandmark.LEFT_WRIST]
                wrist_right = landmarks[mp_pose.PoseLandmark.RIGHT_WRIST]
                hip_left = landmarks[mp_pose.PoseLandmark.LEFT_HIP]
                hip_right = landmarks[mp_pose.PoseLandmark.RIGHT_HIP]
                knee_left = landmarks[mp_pose.PoseLandmark.LEFT_KNEE]
                knee_right = landmarks[mp_pose.PoseLandmark.RIGHT_KNEE]
                ankle_left = landmarks[mp_pose.PoseLandmark.LEFT_ANKLE]
                ankle_right = landmarks[mp_pose.PoseLandmark.RIGHT_ANKLE]

                # Calculate wrist and elbow positions for tracking
                wrist_x = wrist_right.x * frame_width
                wrist_y = wrist_right.y * frame_height
                current_wrist_pos = (wrist_x, wrist_y)
                
                elbow_x = elbow_right.x * frame_width
                elbow_y = elbow_right.y * frame_height
                current_elbow_pos = (elbow_x, elbow_y)

                # Detect serving phase (when wrist starts moving upward)
                if prev_wrist_position is not None:
                    if wrist_y < prev_wrist_position[1] and not serving_phase:
                        serving_phase = True
                        wrist_positions = []
                        print("Serve motion detected!")
                    
                    if serving_phase:
                        wrist_positions.append(current_wrist_pos)
                        if len(wrist_positions) > max_wrist_positions:
                            wrist_positions.pop(0)
                        
                        # Calculate arc curvature
                        if len(wrist_positions) >= 3:
                            arc_curvature = calculate_arc_curvature(wrist_positions)
                            max_arc_curvature = max(max_arc_curvature, arc_curvature)

                # Calculate wrist angular rotation
                if prev_wrist_position is not None and prev_elbow_position is not None:
                    angle_diff = calculate_wrist_rotation(prev_wrist_position, current_wrist_pos, 
                                                        prev_elbow_position, current_elbow_pos)
                    
                    wrist_rotation_angle += angle_diff
                    
                    # Store recent angle differences for angular velocity calculation
                    wrist_angle_differences.append(angle_diff)
                    if len(wrist_angle_differences) > 5:
                        wrist_angle_differences.pop(0)
                    
                    # Calculate angular velocity
                    current_angular_velocity = calculate_angular_velocity(wrist_angle_differences, fps)
                    max_angular_velocity = max(max_angular_velocity, abs(current_angular_velocity))

                # Draw wrist arc
                if len(wrist_positions) >= 2:
                    for i in range(1, len(wrist_positions)):
                        cv2.line(frame, 
                                (int(wrist_positions[i-1][0]), int(wrist_positions[i-1][1])),
                                (int(wrist_positions[i][0]), int(wrist_positions[i][1])),
                                (0, 255, 255), 3)

                # Draw current wrist position
                cv2.circle(frame, (int(wrist_x), int(wrist_y)), 10, (0, 0, 255), -1)

                # Calculate metrics
                upper_body_tilt = calculate_tilt(shoulder_left, shoulder_right)
                arm_angle = calculate_angle(shoulder_right, elbow_right, wrist_right)
                elbow_flexion = calculate_angle(shoulder_right, elbow_right, wrist_right)
                wrist_flexion = calculate_angle(elbow_right, wrist_right, (wrist_right.x + 0.1, wrist_right.y))
                
                if prev_wrist_position is not None:
                    arm_speed = calculate_speed(prev_wrist_position, current_wrist_pos, fps)
                    calculated_metrics[12] = arm_speed

                # Detect ball release and racquet contact based on wrist movement
                if prev_wrist_position is not None:
                    current_wrist_y = wrist_right.y * frame_height
                    
                    # Ball release: when wrist starts moving upward (y decreases)
                    if current_wrist_y < prev_wrist_position[1]:
                        if ball_release_time is None:
                            ball_release_time = timestamp_ms / 1000
                            calculated_metrics[14] = ball_release_time
                    
                    # Racquet contact: when wrist starts moving downward after release (y increases)
                    if ball_release_time is not None and current_wrist_y > prev_wrist_position[1]:
                        if racquet_contact_time is None:
                            racquet_contact_time = timestamp_ms / 1000
                            calculated_metrics[15] = racquet_contact_time
                            serving_phase = False

                # Update previous positions
                prev_wrist_position = current_wrist_pos
                prev_elbow_position = current_elbow_pos

                left_knee_flexion = calculate_angle(hip_left, knee_left, ankle_left)
                right_knee_flexion = calculate_angle(hip_right, knee_right, ankle_right)
                
                # Calculate ball height based on wrist position
                current_ball_height_cm = (frame_height - wrist_y) * conversion_factor
                if current_ball_height_cm > max_ball_height_cm:
                    max_ball_height_cm = current_ball_height_cm

                if ball_release_time is not None and racquet_contact_time is not None:
                    service_motion_time = racquet_contact_time - ball_release_time
                    calculated_metrics[13] = service_motion_time

                ball_projection_angle = calculate_angle(shoulder_right, wrist_right, (wrist_right.x + 0.1, wrist_right.y))
                lower_body_tilt = calculate_tilt(hip_left, hip_right)
                
                shoulder_midpoint = ((shoulder_left.x + shoulder_right.x) / 2, (shoulder_left.y + shoulder_right.y) / 2)
                hip_midpoint = ((hip_left.x + hip_right.x) / 2, (hip_left.y + hip_right.y) / 2)
                trunk_tilt = calculate_tilt(shoulder_midpoint, hip_midpoint)

                # Calculated metrics
                calculated_metrics[0] = upper_body_tilt
                calculated_metrics[1] = arm_angle
                calculated_metrics[2] = elbow_flexion
                calculated_metrics[3] = wrist_flexion
                calculated_metrics[4] = left_knee_flexion
                calculated_metrics[5] = right_knee_flexion
                calculated_metrics[6] = current_ball_height_cm
                calculated_metrics[7] = max_ball_height_cm
                calculated_metrics[8] = ball_ankle_height_cm
                calculated_metrics[9] = ball_projection_angle
                calculated_metrics[10] = lower_body_tilt
                calculated_metrics[11] = trunk_tilt
                calculated_metrics[16] = arc_curvature
                calculated_metrics[17] = wrist_rotation_angle
                calculated_metrics[18] = current_angular_velocity

                # Display results on frame
                y_offset = 30
                cv2.putText(frame, f"Wrist Arc Curvature: {arc_curvature:.1f} deg", (10, y_offset), 
                           cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 255, 255), 2)
                y_offset += 30
                cv2.putText(frame, f"Wrist Rotation: {wrist_rotation_angle:.1f} deg", (10, y_offset), 
                           cv2.FONT_HERSHEY_SIMPLEX, 0.7, (255, 255, 0), 2)
                y_offset += 30
                cv2.putText(frame, f"Angular Velocity: {current_angular_velocity:.1f} deg/s", (10, y_offset), 
                           cv2.FONT_HERSHEY_SIMPLEX, 0.7, (255, 255, 0), 2)
                y_offset += 30
                #cv2.putText(frame, f"Arm Speed: {arm_speed:.1f} px/s" if prev_wrist_position is not None else "Arm Speed: -", 
                #           (10, y_offset), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 255, 0), 2)
                #y_offset += 25
                cv2.putText(frame, f"Ball Height: {current_ball_height_cm:.1f} cm", (10, y_offset), 
                           cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 255, 0), 2)

                # Add visual indicator for wrist rotation direction
                rotation_indicator_x = frame_width - 100
                rotation_indicator_y = 100
                rotation_radius = 30

                # Draw rotation indicator circle
                cv2.circle(frame, (rotation_indicator_x, rotation_indicator_y), rotation_radius, (255, 255, 255), 2)

                # Draw rotation direction arrow
                if abs(current_angular_velocity) > 10:
                    arrow_length = 25
                    if current_angular_velocity > 0:
                        # Clockwise rotation
                        cv2.arrowedLine(frame, 
                                       (rotation_indicator_x, rotation_indicator_y - arrow_length),
                                       (rotation_indicator_x, rotation_indicator_y + arrow_length),
                                       (0, 255, 0), 3)
                        cv2.putText(frame, "CW", (rotation_indicator_x - 15, rotation_indicator_y - 40),
                                   cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 255, 0), 2)
                    else:
                        # Counter-clockwise rotation
                        cv2.arrowedLine(frame, 
                                       (rotation_indicator_x, rotation_indicator_y + arrow_length),
                                       (rotation_indicator_x, rotation_indicator_y - arrow_length),
                                       (0, 0, 255), 3)
                        cv2.putText(frame, "CCW", (rotation_indicator_x - 20, rotation_indicator_y - 40),
                                   cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 0, 255), 2)

                # Add text label for rotation indicator
                cv2.putText(frame, "Wrist Rotation", (rotation_indicator_x - 50, rotation_indicator_y + 60),
                           cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 1)

                # Draw elbow-wrist line to visualize the rotation
                cv2.line(frame, 
                        (int(elbow_x), int(elbow_y)),
                        (int(wrist_x), int(wrist_y)),
                        (255, 255, 0), 2)

                # Draw angle arc between consecutive elbow-wrist vectors
                if len(wrist_positions) >= 2 and len(wrist_angle_differences) > 0:
                    current_angle = math.degrees(math.atan2(wrist_y - elbow_y, wrist_x - elbow_x))
                    start_angle = current_angle - 30
                    end_angle = current_angle + 30
                    cv2.ellipse(frame, (int(wrist_x), int(wrist_y)), (20, 20), 0, 
                                start_angle, end_angle, (255, 100, 0), 2)

            # Process ball detection
            ball_detections = None
            if yolo_model_ball:
                try:
                    results_yolo_ball = yolo_model_ball(frame, conf=0.1)
                    if results_yolo_ball:
                        for result in results_yolo_ball:
                            boxes = result.boxes
                            for box in boxes:
                                if box.cls == 0:
                                    x1, y1, x2, y2 = box.xyxy[0].cpu().numpy()
                                    ball_data = [(x1 + x2) / 2, (y1 + y2) / 2, box.conf.cpu().numpy()[0]]
                                    cv2.rectangle(frame, (int(x1), int(y1)), (int(x2), int(y2)), (0, 255, 0), 2)
                except:
                    ball_detections = detect_ball_simple(frame)
            else:
                ball_detections = detect_ball_simple(frame)
            
            if ball_detections:
                for x, y, conf in ball_detections:
                    cv2.circle(frame, (int(x), int(y)), 15, (0, 255, 0), 2)
                    ball_data = [x, y, conf]

            # Process racquet detection
            racquet_detections = None
            if yolo_model_racquet:
                try:
                    results_yolo_racquet = yolo_model_racquet(frame, conf=0.1)
                    if results_yolo_racquet:
                        for result in results_yolo_racquet:
                            boxes = result.boxes
                            for box in boxes:
                                if box.cls == 0:
                                    x1, y1, x2, y2 = box.xyxy[0].cpu().numpy()
                                    racquet_data = [(x1 + x2) / 2, (y1 + y2) / 2, box.conf.cpu().numpy()[0]]
                                    cv2.rectangle(frame, (int(x1), int(y1)), (int(x2), int(y2)), (255, 0, 0), 2)
                except:
                    racquet_detections = detect_racquet_simple(frame)
            else:
                racquet_detections = detect_racquet_simple(frame)
            
            if racquet_detections:
                for x, y, conf in racquet_detections:
                    cv2.circle(frame, (int(x), int(y)), 20, (255, 0, 0), 2)
                    racquet_data = [x, y, conf]

            # Combine all data and write to CSV
            row_data.extend(landmark_data)
            row_data.extend(ball_data)
            row_data.extend(racquet_data)
            row_data.extend(calculated_metrics)
            csv_writer.writerow(row_data)

            # Write the frame to the output video
            out.write(frame)

        # Release resources for this video
        cap.release()
        out.release()

        print(f"\nProcessed video {video_file} saved to: {output_video_path}")
        print(f"Analysis data saved to: {csv_filename}")
        print(f"Maximum Ball Height: {max_ball_height_cm:.2f} cm")
        print(f"Maximum Wrist Arc Curvature: {max_arc_curvature:.2f} deg")
        print(f"Maximum Angular Velocity: {max_angular_velocity:.2f} deg/s")
        if service_motion_time is not None:
            print(f"Service Motion Time: {service_motion_time:.3f} s")

print("\nAll videos processed successfully!")
# Out:
# 0: 384x640 1 ball, 1707.8ms
# Speed: 0.0ms preprocess, 1707.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 racquet , 791.7ms
# Speed: 0.0ms preprocess, 791.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Serve motion detected!
#
# 0: 384x640 (no detections), 1694.3ms
# Speed: 0.0ms preprocess, 1694.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 racquet , 799.1ms
# Speed: 6.7ms preprocess, 799.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1687.9ms
# Speed: 6.6ms preprocess, 1687.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 racquet , 796.2ms
# Speed: 3.9ms preprocess, 796.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1673.6ms
# Speed: 0.0ms preprocess, 1673.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 racquet , 770.6ms
# Speed: 6.6ms preprocess, 770.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1709.0ms
# Speed: 0.0ms preprocess, 1709.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 racquet , 781.0ms
# Speed: 3.2ms preprocess, 781.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Serve motion detected!
#
# 0: 384x640 1 ball, 1670.0ms
# Speed: 1.3ms preprocess, 1670.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 racquet , 775.1ms
# Speed: 3.2ms preprocess, 775.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 balls, 1652.5ms
# Speed: 0.0ms preprocess, 1652.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 racquet , 782.8ms
# Speed: 0.0ms preprocess, 782.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 balls, 1683.1ms
# Speed: 0.0ms preprocess, 1683.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 racquet s, 769.2ms
# Speed: 2.5ms preprocess, 769.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1652.5ms
# Speed: 2.1ms preprocess, 1652.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 racquet , 785.3ms
# Speed: 3.3ms preprocess, 785.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1660.0ms
# Speed: 6.5ms preprocess, 1660.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 racquet , 782.9ms
# Speed: 0.5ms preprocess, 782.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1652.5ms
# Speed: 0.0ms preprocess, 1652.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 775.5ms
# Speed: 8.4ms preprocess, 775.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1649.6ms
# Speed: 2.2ms preprocess, 1649.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 racquet , 791.2ms
# Speed: 1.4ms preprocess, 791.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1653.5ms
# Speed: 3.5ms preprocess, 1653.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 783.9ms
# Speed: 6.7ms preprocess, 783.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1672.5ms
# Speed: 2.3ms preprocess, 1672.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 racquet , 788.9ms
# Speed: 0.0ms preprocess, 788.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1660.1ms
# Speed: 0.0ms preprocess, 1660.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 racquet , 810.3ms
# Speed: 2.9ms preprocess, 810.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1656.0ms
# Speed: 6.7ms preprocess, 1656.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 racquet s, 786.9ms
# Speed: 3.6ms preprocess, 786.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1665.2ms
# Speed: 2.8ms preprocess, 1665.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 racquet s, 775.1ms
# Speed: 2.0ms preprocess, 775.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1671.1ms
# Speed: 2.0ms preprocess, 1671.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 racquet s, 791.0ms
# Speed: 2.5ms preprocess, 791.0ms inference, 6.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1637.0ms
# Speed: 0.0ms preprocess, 1637.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 racquet , 771.7ms
# Speed: 0.0ms preprocess, 771.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1644.9ms
# Speed: 0.0ms preprocess, 1644.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 racquet s, 777.0ms
# Speed: 0.0ms preprocess, 777.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1630.3ms
# Speed: 7.5ms preprocess, 1630.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 racquet s, 779.9ms
# Speed: 3.0ms preprocess, 779.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1648.6ms
# Speed: 3.1ms preprocess, 1648.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 racquet s, 769.7ms
# Speed: 3.1ms preprocess, 769.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1676.5ms
# Speed: 2.2ms preprocess, 1676.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 racquet s, 763.6ms
# Speed: 3.5ms preprocess, 763.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1643.6ms
# Speed: 2.5ms preprocess, 1643.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 racquet s, 769.4ms
# Speed: 2.0ms preprocess, 769.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1635.9ms
# Speed: 2.1ms preprocess, 1635.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 racquet s, 782.9ms
# Speed: 0.0ms preprocess, 782.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1644.4ms
# Speed: 3.2ms preprocess, 1644.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 racquet s, 775.0ms
# Speed: 0.0ms preprocess, 775.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1665.6ms
# Speed: 1.3ms preprocess, 1665.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 racquet s, 768.2ms
# Speed: 3.3ms preprocess, 768.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1666.6ms
# Speed: 2.0ms preprocess, 1666.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 racquet s, 778.6ms
# Speed: 1.1ms preprocess, 778.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1779.9ms
# Speed: 7.8ms preprocess, 1779.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 racquet s, 775.0ms
# Speed: 2.5ms preprocess, 775.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1658.1ms
# Speed: 2.9ms preprocess, 1658.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 racquet s, 789.9ms
# Speed: 5.0ms preprocess, 789.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1639.9ms
# Speed: 1.2ms preprocess, 1639.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 racquet s, 769.6ms
# Speed: 2.0ms preprocess, 769.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1640.9ms
# Speed: 2.8ms preprocess, 1640.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 racquet s, 766.0ms
# Speed: 1.8ms preprocess, 766.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1629.2ms
# Speed: 6.2ms preprocess, 1629.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 racquet s, 773.4ms
# Speed: 2.0ms preprocess, 773.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1634.1ms
# Speed: 2.1ms preprocess, 1634.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 racquet , 778.2ms
# Speed: 0.0ms preprocess, 778.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 balls, 1640.4ms
# Speed: 1.6ms preprocess, 1640.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 racquet s, 763.0ms
# Speed: 2.5ms preprocess, 763.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1638.6ms
# Speed: 0.0ms preprocess, 1638.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 racquet s, 775.1ms
# Speed: 2.3ms preprocess, 775.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 balls, 1645.2ms
# Speed: 0.0ms preprocess, 1645.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 racquet s, 782.1ms
# Speed: 6.4ms preprocess, 782.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1666.6ms
# Speed: 0.0ms preprocess, 1666.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 racquet s, 779.5ms
# Speed: 0.0ms preprocess, 779.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1638.4ms
# Speed: 2.0ms preprocess, 1638.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 racquet s, 767.2ms
# Speed: 2.1ms preprocess, 767.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1632.0ms
# Speed: 7.9ms preprocess, 1632.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 racquet s, 769.2ms
# Speed: 2.4ms preprocess, 769.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1701.9ms
# Speed: 0.0ms preprocess, 1701.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 racquet s, 785.5ms
# Speed: 2.8ms preprocess, 785.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1693.0ms
# Speed: 0.0ms preprocess, 1693.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 racquet s, 778.6ms
# Speed: 3.1ms preprocess, 778.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1656.6ms
# Speed: 0.0ms preprocess, 1656.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 racquet s, 768.8ms
# Speed: 5.6ms preprocess, 768.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1639.6ms
# Speed: 2.4ms preprocess, 1639.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 racquet s, 768.2ms
# Speed: 3.3ms preprocess, 768.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1807.9ms
# Speed: 2.7ms preprocess, 1807.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 racquet , 775.1ms
# Speed: 3.2ms preprocess, 775.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1634.1ms
# Speed: 2.8ms preprocess, 1634.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 racquet s, 817.8ms
# Speed: 0.5ms preprocess, 817.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1657.4ms
# Speed: 7.3ms preprocess, 1657.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 racquet s, 765.7ms
# Speed: 0.0ms preprocess, 765.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1642.0ms
# Speed: 2.0ms preprocess, 1642.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 racquet s, 760.2ms
# Speed: 3.5ms preprocess, 760.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1618.1ms
# Speed: 2.2ms preprocess, 1618.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 racquet s, 770.8ms
# Speed: 4.7ms preprocess, 770.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1634.8ms
# Speed: 2.3ms preprocess, 1634.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 racquet s, 788.9ms
# Speed: 1.0ms preprocess, 788.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1705.8ms
# Speed: 3.0ms preprocess, 1705.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 racquet s, 840.9ms
# Speed: 0.0ms preprocess, 840.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1635.9ms
# Speed: 3.1ms preprocess, 1635.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 racquet s, 769.1ms
# Speed: 2.5ms preprocess, 769.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1621.3ms
# Speed: 2.4ms preprocess, 1621.3ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 racquet s, 775.7ms
# Speed: 3.0ms preprocess, 775.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1629.6ms
# Speed: 3.7ms preprocess, 1629.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 racquet , 770.2ms
# Speed: 4.1ms preprocess, 770.2ms inference, 6.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1670.5ms
# Speed: 3.2ms preprocess, 1670.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 racquet , 763.3ms
# Speed: 7.5ms preprocess, 763.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1629.7ms
# Speed: 2.1ms preprocess, 1629.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 racquet , 766.9ms
# Speed: 3.1ms preprocess, 766.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1627.8ms
# Speed: 0.0ms preprocess, 1627.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 racquet s, 774.8ms
# Speed: 0.7ms preprocess, 774.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1690.2ms
# Speed: 6.0ms preprocess, 1690.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 racquet s, 773.5ms
# Speed: 1.2ms preprocess, 773.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1623.8ms
# Speed: 2.2ms preprocess, 1623.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 racquet s, 766.8ms
# Speed: 0.7ms preprocess, 766.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1644.1ms
# Speed: 2.5ms preprocess, 1644.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 racquet s, 774.3ms
# Speed: 2.2ms preprocess, 774.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1655.5ms
# Speed: 2.0ms preprocess, 1655.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 racquet s, 771.2ms
# Speed: 3.6ms preprocess, 771.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1628.2ms
# Speed: 7.4ms preprocess, 1628.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 racquet s, 774.9ms
# Speed: 0.0ms preprocess, 774.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# Processed video 1.mp4 saved to: D:\DDSA\Serve Pose Detection\Output video\1_output_video.mp4
# Analysis data saved to: D:\DDSA\Serve Pose Detection\Output video\1_analysis_20251004_131050.csv
# Maximum Ball Height: 1510.01 cm
# Maximum Wrist Arc Curvature: 61.56 deg
# Maximum Angular Velocity: 774.09 deg/s
# Service Motion Time: 0.080 s
#
# 0: 384x640 (no detections), 1662.6ms
# Speed: 3.0ms preprocess, 1662.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 racquet s, 790.8ms
# Speed: 8.7ms preprocess, 790.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1666.7ms
# Speed: 2.0ms preprocess, 1666.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 racquet s, 771.7ms
# Speed: 7.6ms preprocess, 771.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1660.9ms
# Speed: 2.0ms preprocess, 1660.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 racquet s, 767.3ms
# Speed: 2.0ms preprocess, 767.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1622.9ms
# Speed: 2.4ms preprocess, 1622.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 racquet s, 769.9ms
# Speed: 3.1ms preprocess, 769.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1657.8ms
# Speed: 0.0ms preprocess, 1657.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 racquet s, 777.2ms
# Speed: 0.0ms preprocess, 777.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1655.3ms
# Speed: 2.0ms preprocess, 1655.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 racquet s, 775.8ms
# Speed: 7.1ms preprocess, 775.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1629.5ms
# Speed: 2.4ms preprocess, 1629.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 racquet s, 815.1ms
# Speed: 2.3ms preprocess, 815.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Serve motion detected!
#
# 0: 384x640 (no detections), 1641.9ms
# Speed: 2.4ms preprocess, 1641.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 racquet s, 767.0ms
# Speed: 0.0ms preprocess, 767.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1784.0ms
# Speed: 1.9ms preprocess, 1784.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 racquet s, 812.8ms
# Speed: 4.7ms preprocess, 812.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1727.2ms
# Speed: 3.1ms preprocess, 1727.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 racquet s, 767.5ms
# Speed: 6.2ms preprocess, 767.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1632.7ms
# Speed: 0.0ms preprocess, 1632.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 racquet s, 777.7ms
# Speed: 0.0ms preprocess, 777.7ms inference, 6.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1626.2ms
# Speed: 0.0ms preprocess, 1626.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 770.8ms
# Speed: 3.4ms preprocess, 770.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1645.2ms
# Speed: 0.8ms preprocess, 1645.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 racquet , 773.2ms
# Speed: 3.4ms preprocess, 773.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1653.0ms
# Speed: 7.3ms preprocess, 1653.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 768.5ms
# Speed: 6.4ms preprocess, 768.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1638.6ms
# Speed: 0.0ms preprocess, 1638.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 782.7ms
# Speed: 0.6ms preprocess, 782.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1631.9ms
# Speed: 2.2ms preprocess, 1631.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 784.9ms
# Speed: 2.8ms preprocess, 784.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1701.3ms
# Speed: 0.0ms preprocess, 1701.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 racquet , 770.0ms
# Speed: 7.7ms preprocess, 770.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1633.4ms
# Speed: 4.5ms preprocess, 1633.4ms inference, 7.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 765.8ms
# Speed: 3.1ms preprocess, 765.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1627.1ms
# Speed: 5.5ms preprocess, 1627.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 781.7ms
# Speed: 0.0ms preprocess, 781.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1627.7ms
# Speed: 2.0ms preprocess, 1627.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 racquet , 769.5ms
# Speed: 3.4ms preprocess, 769.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1643.0ms
# Speed: 2.0ms preprocess, 1643.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 racquet s, 756.1ms
# Speed: 5.2ms preprocess, 756.1ms inference, 6.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1637.7ms
# Speed: 0.0ms preprocess, 1637.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 racquet , 774.2ms
# Speed: 0.0ms preprocess, 774.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1633.6ms
# Speed: 2.0ms preprocess, 1633.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 771.6ms
# Speed: 2.0ms preprocess, 771.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1688.8ms
# Speed: 2.3ms preprocess, 1688.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 racquet , 769.7ms
# Speed: 2.0ms preprocess, 769.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1641.7ms
# Speed: 2.1ms preprocess, 1641.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 798.6ms
# Speed: 0.0ms preprocess, 798.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1641.6ms
# Speed: 3.0ms preprocess, 1641.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 racquet s, 777.8ms
# Speed: 3.3ms preprocess, 777.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1626.6ms
# Speed: 2.0ms preprocess, 1626.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 771.6ms
# Speed: 7.2ms preprocess, 771.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1638.7ms
# Speed: 2.6ms preprocess, 1638.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 775.4ms
# Speed: 3.0ms preprocess, 775.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1657.8ms
# Speed: 1.9ms preprocess, 1657.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 racquet , 762.8ms
# Speed: 7.4ms preprocess, 762.8ms inference, 6.6ms postprocess per image at shape (1, 3, 384, 640)
# Serve motion detected!
#
# 0: 384x640 (no detections), 1638.0ms
# Speed: 2.6ms preprocess, 1638.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 774.4ms
# Speed: 0.0ms preprocess, 774.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1639.2ms
# Speed: 2.4ms preprocess, 1639.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 racquet s, 771.2ms
# Speed: 7.0ms preprocess, 771.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1626.5ms
# Speed: 6.1ms preprocess, 1626.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 763.6ms
# Speed: 3.4ms preprocess, 763.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1644.6ms
# Speed: 3.1ms preprocess, 1644.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 racquet , 769.1ms
# Speed: 2.1ms preprocess, 769.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1640.3ms
# Speed: 0.0ms preprocess, 1640.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 racquet s, 764.0ms
# Speed: 2.8ms preprocess, 764.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1623.3ms
# Speed: 2.0ms preprocess, 1623.3ms inference, 6.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 racquet s, 772.0ms
# Speed: 2.2ms preprocess, 772.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1638.0ms
# Speed: 7.3ms preprocess, 1638.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 racquet s, 765.6ms
# Speed: 2.0ms preprocess, 765.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1643.8ms
# Speed: 3.6ms preprocess, 1643.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 racquet s, 769.5ms
# Speed: 0.0ms preprocess, 769.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1673.6ms
# Speed: 2.0ms preprocess, 1673.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 racquet , 773.0ms
# Speed: 3.1ms preprocess, 773.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1636.9ms
# Speed: 5.8ms preprocess, 1636.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 racquet , 790.3ms
# Speed: 5.2ms preprocess, 790.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1629.0ms
# Speed: 2.4ms preprocess, 1629.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 racquet s, 774.4ms
# Speed: 3.6ms preprocess, 774.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1647.7ms
# Speed: 2.5ms preprocess, 1647.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 racquet , 763.4ms
# Speed: 7.5ms preprocess, 763.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1630.1ms
# Speed: 2.3ms preprocess, 1630.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 racquet s, 762.0ms
# Speed: 4.5ms preprocess, 762.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1620.9ms
# Speed: 2.4ms preprocess, 1620.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 777.7ms
# Speed: 0.0ms preprocess, 777.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1638.9ms
# Speed: 0.0ms preprocess, 1638.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 racquet s, 780.7ms
# Speed: 0.0ms preprocess, 780.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1758.7ms
# Speed: 3.7ms preprocess, 1758.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 768.0ms
# Speed: 3.4ms preprocess, 768.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1631.9ms
# Speed: 0.0ms preprocess, 1631.9ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 772.6ms
# Speed: 3.0ms preprocess, 772.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1637.9ms
# Speed: 2.6ms preprocess, 1637.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 racquet , 773.4ms
# Speed: 4.2ms preprocess, 773.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1660.4ms
# Speed: 0.0ms preprocess, 1660.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 766.1ms
# Speed: 2.6ms preprocess, 766.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1638.4ms
# Speed: 0.0ms preprocess, 1638.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 771.4ms
# Speed: 2.4ms preprocess, 771.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1639.9ms
# Speed: 2.1ms preprocess, 1639.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 777.9ms
# Speed: 0.0ms preprocess, 777.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1630.5ms
# Speed: 4.7ms preprocess, 1630.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 778.0ms
# Speed: 2.0ms preprocess, 778.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1666.7ms
# Speed: 6.5ms preprocess, 1666.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 779.1ms
# Speed: 2.0ms preprocess, 779.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1649.6ms
# Speed: 0.7ms preprocess, 1649.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 racquet , 770.3ms
# Speed: 2.1ms preprocess, 770.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1665.0ms
# Speed: 2.1ms preprocess, 1665.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 825.4ms
# Speed: 2.4ms preprocess, 825.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1683.0ms
# Speed: 7.9ms preprocess, 1683.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 racquet s, 775.8ms
# Speed: 1.2ms preprocess, 775.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1668.9ms
# Speed: 3.4ms preprocess, 1668.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 777.2ms
# Speed: 2.4ms preprocess, 777.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1640.9ms
# Speed: 3.1ms preprocess, 1640.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 racquet , 768.9ms
# Speed: 6.3ms preprocess, 768.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1638.3ms
# Speed: 0.0ms preprocess, 1638.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 racquet s, 786.9ms
# Speed: 0.0ms preprocess, 786.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1657.0ms
# Speed: 2.0ms preprocess, 1657.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 racquet s, 779.5ms
# Speed: 3.1ms preprocess, 779.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1625.1ms
# Speed: 4.9ms preprocess, 1625.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 racquet s, 764.1ms
# Speed: 6.5ms preprocess, 764.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1623.6ms
# Speed: 6.2ms preprocess, 1623.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 racquet , 791.5ms
# Speed: 2.3ms preprocess, 791.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1637.8ms
# Speed: 3.0ms preprocess, 1637.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 racquet , 778.7ms
# Speed: 2.1ms preprocess, 778.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1914.8ms
# Speed: 2.2ms preprocess, 1914.8ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 racquet , 769.4ms
# Speed: 6.4ms preprocess, 769.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1628.1ms
# Speed: 2.5ms preprocess, 1628.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 racquet s, 761.1ms
# Speed: 2.0ms preprocess, 761.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1643.5ms
# Speed: 1.8ms preprocess, 1643.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 racquet s, 774.7ms
# Speed: 3.2ms preprocess, 774.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1625.8ms
# Speed: 2.4ms preprocess, 1625.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 racquet s, 770.7ms
# Speed: 0.0ms preprocess, 770.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1626.0ms
# Speed: 5.3ms preprocess, 1626.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 racquet , 765.8ms
# Speed: 3.4ms preprocess, 765.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1633.7ms
# Speed: 5.4ms preprocess, 1633.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 racquet s, 787.4ms
# Speed: 3.7ms preprocess, 787.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1639.0ms
# Speed: 2.3ms preprocess, 1639.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 racquet , 784.6ms
# Speed: 2.4ms preprocess, 784.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# Processed video 2.mp4 saved to: D:\DDSA\Serve Pose Detection\Output video\2_output_video.mp4
# Analysis data saved to: D:\DDSA\Serve Pose Detection\Output video\2_analysis_20251004_131326.csv
# Maximum Ball Height: 1059.33 cm
# Maximum Wrist Arc Curvature: 44.14 deg
# Maximum Angular Velocity: 1160.34 deg/s
# Service Motion Time: 0.667 s
#
# 0: 384x640 (no detections), 1790.9ms
# Speed: 0.8ms preprocess, 1790.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 racquet s, 798.8ms
# Speed: 0.0ms preprocess, 798.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1637.2ms
# Speed: 8.5ms preprocess, 1637.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 racquet s, 782.9ms
# Speed: 6.7ms preprocess, 782.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Serve motion detected!
#
# 0: 384x640 (no detections), 1625.5ms
# Speed: 5.4ms preprocess, 1625.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 racquet s, 768.6ms
# Speed: 2.3ms preprocess, 768.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1678.4ms
# Speed: 0.0ms preprocess, 1678.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 racquet s, 780.7ms
# Speed: 3.0ms preprocess, 780.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1658.8ms
# Speed: 2.0ms preprocess, 1658.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 racquet s, 785.5ms
# Speed: 0.0ms preprocess, 785.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1635.7ms
# Speed: 0.0ms preprocess, 1635.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 racquet s, 796.5ms
# Speed: 0.0ms preprocess, 796.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1632.7ms
# Speed: 0.0ms preprocess, 1632.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 racquet s, 763.7ms
# Speed: 6.3ms preprocess, 763.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1679.8ms
# Speed: 1.8ms preprocess, 1679.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 racquet s, 771.6ms
# Speed: 5.8ms preprocess, 771.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1640.5ms
# Speed: 2.0ms preprocess, 1640.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 racquet s, 779.9ms
# Speed: 0.0ms preprocess, 779.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1639.1ms
# Speed: 0.0ms preprocess, 1639.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 racquet s, 774.6ms
# Speed: 4.9ms preprocess, 774.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1674.4ms
# Speed: 0.0ms preprocess, 1674.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 racquet s, 771.7ms
# Speed: 4.2ms preprocess, 771.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1639.2ms
# Speed: 2.5ms preprocess, 1639.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 racquet s, 777.0ms
# Speed: 0.0ms preprocess, 777.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1646.9ms
# Speed: 7.6ms preprocess, 1646.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 racquet s, 771.9ms
# Speed: 2.0ms preprocess, 771.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1639.5ms
# Speed: 2.3ms preprocess, 1639.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 racquet s, 779.0ms
# Speed: 0.5ms preprocess, 779.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1630.3ms
# Speed: 2.2ms preprocess, 1630.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 racquet s, 764.7ms
# Speed: 3.0ms preprocess, 764.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1628.9ms
# Speed: 2.0ms preprocess, 1628.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 racquet s, 764.1ms
# Speed: 2.6ms preprocess, 764.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 balls, 1632.4ms
# Speed: 7.2ms preprocess, 1632.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 racquet s, 770.3ms
# Speed: 7.5ms preprocess, 770.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 balls, 1694.1ms
# Speed: 0.0ms preprocess, 1694.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 racquet s, 798.1ms
# Speed: 0.0ms preprocess, 798.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 balls, 1693.3ms
# Speed: 5.9ms preprocess, 1693.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 racquet s, 764.8ms
# Speed: 3.5ms preprocess, 764.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1668.4ms
# Speed: 1.5ms preprocess, 1668.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 racquet s, 776.6ms
# Speed: 0.0ms preprocess, 776.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Serve motion detected!
#
# 0: 384x640 (no detections), 1660.0ms
# Speed: 0.0ms preprocess, 1660.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 racquet s, 777.9ms
# Speed: 2.1ms preprocess, 777.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1625.3ms
# Speed: 2.7ms preprocess, 1625.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 racquet s, 768.1ms
# Speed: 3.5ms preprocess, 768.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1637.9ms
# Speed: 0.0ms preprocess, 1637.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 racquet s, 772.6ms
# Speed: 0.0ms preprocess, 772.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1639.5ms
# Speed: 3.0ms preprocess, 1639.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 racquet s, 799.1ms
# Speed: 3.2ms preprocess, 799.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1680.9ms
# Speed: 0.0ms preprocess, 1680.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 racquet s, 766.7ms
# Speed: 3.0ms preprocess, 766.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1625.8ms
# Speed: 2.0ms preprocess, 1625.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 racquet s, 770.3ms
# Speed: 0.0ms preprocess, 770.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1623.5ms
# Speed: 6.1ms preprocess, 1623.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 racquet s, 766.2ms
# Speed: 2.0ms preprocess, 766.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1630.2ms
# Speed: 2.0ms preprocess, 1630.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 racquet s, 764.9ms
# Speed: 2.0ms preprocess, 764.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1638.3ms
# Speed: 7.2ms preprocess, 1638.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 racquet s, 771.1ms
# Speed: 6.8ms preprocess, 771.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1620.2ms
# Speed: 2.0ms preprocess, 1620.2ms inference, 7.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 racquet s, 770.9ms
# Speed: 0.0ms preprocess, 770.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1654.5ms
# Speed: 3.0ms preprocess, 1654.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 racquet s, 764.9ms
# Speed: 0.0ms preprocess, 764.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1664.2ms
# Speed: 3.3ms preprocess, 1664.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 racquet s, 775.0ms
# Speed: 8.4ms preprocess, 775.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1668.9ms
# Speed: 2.0ms preprocess, 1668.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 racquet s, 780.4ms
# Speed: 0.0ms preprocess, 780.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1625.3ms
# Speed: 6.6ms preprocess, 1625.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 racquet s, 756.6ms
# Speed: 6.4ms preprocess, 756.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1635.9ms
# Speed: 0.0ms preprocess, 1635.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 racquet s, 767.6ms
# Speed: 4.1ms preprocess, 767.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1627.3ms
# Speed: 2.4ms preprocess, 1627.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 racquet s, 766.1ms
# Speed: 2.1ms preprocess, 766.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1632.2ms
# Speed: 3.3ms preprocess, 1632.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 racquet s, 775.0ms
# Speed: 0.0ms preprocess, 775.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1622.4ms
# Speed: 3.4ms preprocess, 1622.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 racquet s, 760.9ms
# Speed: 2.0ms preprocess, 760.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1666.1ms
# Speed: 6.4ms preprocess, 1666.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 racquet s, 774.0ms
# Speed: 0.0ms preprocess, 774.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1628.9ms
# Speed: 2.0ms preprocess, 1628.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 racquet s, 769.2ms
# Speed: 0.0ms preprocess, 769.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1695.6ms
# Speed: 2.1ms preprocess, 1695.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 racquet s, 777.4ms
# Speed: 5.1ms preprocess, 777.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1639.8ms
# Speed: 0.0ms preprocess, 1639.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 racquet s, 764.1ms
# Speed: 6.6ms preprocess, 764.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1626.5ms
# Speed: 1.7ms preprocess, 1626.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 racquet s, 762.5ms
# Speed: 4.2ms preprocess, 762.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1642.7ms
# Speed: 2.5ms preprocess, 1642.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 racquet , 791.0ms
# Speed: 7.5ms preprocess, 791.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1649.9ms
# Speed: 3.4ms preprocess, 1649.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 racquet s, 770.2ms
# Speed: 7.6ms preprocess, 770.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1674.0ms
# Speed: 7.3ms preprocess, 1674.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 racquet s, 763.9ms
# ...
#
# 0: 384x640 (no detections), 1742.6ms
# Speed: 2.7ms preprocess, 1742.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 783.0ms
# Speed: 4.5ms preprocess, 783.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1673.2ms
# Speed: 2.3ms preprocess, 1673.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 835.2ms
# Speed: 3.0ms preprocess, 835.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1688.4ms
# Speed: 3.0ms preprocess, 1688.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 racquet s, 837.9ms
# Speed: 9.3ms preprocess, 837.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1691.0ms
# Speed: 0.0ms preprocess, 1691.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 774.0ms
# Speed: 2.3ms preprocess, 774.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1693.8ms
# Speed: 2.3ms preprocess, 1693.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 797.7ms
# Speed: 2.9ms preprocess, 797.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1769.1ms
# Speed: 2.9ms preprocess, 1769.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 786.6ms
# Speed: 3.1ms preprocess, 786.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1656.6ms
# Speed: 4.7ms preprocess, 1656.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 789.8ms
# Speed: 2.7ms preprocess, 789.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1667.9ms
# Speed: 2.7ms preprocess, 1667.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 770.1ms
# Speed: 2.9ms preprocess, 770.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1716.2ms
# Speed: 1.4ms preprocess, 1716.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 778.2ms
# Speed: 2.5ms preprocess, 778.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1763.5ms
# Speed: 2.5ms preprocess, 1763.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 787.0ms
# Speed: 3.3ms preprocess, 787.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1658.8ms
# Speed: 4.0ms preprocess, 1658.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 780.1ms
# Speed: 2.2ms preprocess, 780.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1724.0ms
# Speed: 6.5ms preprocess, 1724.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 776.0ms
# Speed: 4.2ms preprocess, 776.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1753.5ms
# Speed: 2.2ms preprocess, 1753.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 770.0ms
# Speed: 2.8ms preprocess, 770.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1654.3ms
# Speed: 2.3ms preprocess, 1654.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 775.9ms
# Speed: 2.2ms preprocess, 775.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1646.6ms
# Speed: 2.0ms preprocess, 1646.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 racquet , 809.5ms
# Speed: 6.6ms preprocess, 809.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1770.7ms
# Speed: 2.0ms preprocess, 1770.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 777.3ms
# Speed: 1.1ms preprocess, 777.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1703.9ms
# Speed: 6.3ms preprocess, 1703.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 racquet s, 791.5ms
# Speed: 1.8ms preprocess, 791.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1639.6ms
# Speed: 2.3ms preprocess, 1639.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 757.0ms
# Speed: 2.4ms preprocess, 757.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1611.6ms
# Speed: 1.0ms preprocess, 1611.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 racquet s, 833.1ms
# Speed: 0.0ms preprocess, 833.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1618.7ms
# Speed: 2.4ms preprocess, 1618.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 racquet , 761.0ms
# Speed: 0.0ms preprocess, 761.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1657.2ms
# Speed: 2.5ms preprocess, 1657.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 racquet , 756.9ms
# Speed: 6.2ms preprocess, 756.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1643.4ms
# Speed: 6.2ms preprocess, 1643.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 racquet s, 781.8ms
# Speed: 2.0ms preprocess, 781.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1611.6ms
# Speed: 7.2ms preprocess, 1611.6ms inference, 6.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 racquet , 760.8ms
# Speed: 2.0ms preprocess, 760.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1626.4ms
# Speed: 0.0ms preprocess, 1626.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 racquet s, 758.1ms
# Speed: 2.8ms preprocess, 758.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1656.7ms
# Speed: 3.1ms preprocess, 1656.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 racquet s, 766.4ms
# Speed: 2.1ms preprocess, 766.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1681.0ms
# Speed: 2.2ms preprocess, 1681.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 764.6ms
# Speed: 0.0ms preprocess, 764.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1620.8ms
# Speed: 2.0ms preprocess, 1620.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 757.1ms
# Speed: 2.2ms preprocess, 757.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1626.0ms
# Speed: 2.0ms preprocess, 1626.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 763.2ms
# Speed: 0.0ms preprocess, 763.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1645.8ms
# Speed: 2.0ms preprocess, 1645.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 racquet , 760.3ms
# Speed: 2.1ms preprocess, 760.3ms inference, 7.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1630.2ms
# Speed: 2.0ms preprocess, 1630.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 racquet s, 768.5ms
# Speed: 6.3ms preprocess, 768.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1610.9ms
# Speed: 7.0ms preprocess, 1610.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 racquet s, 752.7ms
# Speed: 2.2ms preprocess, 752.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1628.2ms
# Speed: 2.2ms preprocess, 1628.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 racquet , 762.0ms
# Speed: 2.0ms preprocess, 762.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1668.5ms
# Speed: 2.6ms preprocess, 1668.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 757.3ms
# Speed: 2.6ms preprocess, 757.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1626.1ms
# Speed: 1.0ms preprocess, 1626.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 racquet , 770.6ms
# Speed: 3.0ms preprocess, 770.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1645.1ms
# Speed: 0.0ms preprocess, 1645.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 racquet , 764.3ms
# Speed: 0.0ms preprocess, 764.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1628.1ms
# Speed: 2.1ms preprocess, 1628.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 racquet s, 764.4ms
# Speed: 0.0ms preprocess, 764.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1645.1ms
# Speed: 0.0ms preprocess, 1645.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 racquet , 767.1ms
# Speed: 7.4ms preprocess, 767.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1630.0ms
# Speed: 2.2ms preprocess, 1630.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 racquet , 784.8ms
# Speed: 0.0ms preprocess, 784.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1681.9ms
# Speed: 2.4ms preprocess, 1681.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 760.4ms
# Speed: 2.4ms preprocess, 760.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1615.1ms
# Speed: 3.5ms preprocess, 1615.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 757.6ms
# Speed: 0.0ms preprocess, 757.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1622.3ms
# Speed: 2.4ms preprocess, 1622.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 767.1ms
# Speed: 2.0ms preprocess, 767.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1631.7ms
# Speed: 2.5ms preprocess, 1631.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 786.8ms
# Speed: 3.0ms preprocess, 786.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1614.6ms
# Speed: 3.2ms preprocess, 1614.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 785.8ms
# Speed: 0.0ms preprocess, 785.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1626.8ms
# Speed: 2.2ms preprocess, 1626.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 762.1ms
# Speed: 3.0ms preprocess, 762.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1611.1ms
# Speed: 6.3ms preprocess, 1611.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 racquet , 761.0ms
# Speed: 2.5ms preprocess, 761.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1656.2ms
# Speed: 6.3ms preprocess, 1656.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 racquet s, 777.3ms
# Speed: 1.6ms preprocess, 777.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1625.8ms
# Speed: 0.0ms preprocess, 1625.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 racquet , 757.0ms
# Speed: 0.0ms preprocess, 757.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1616.7ms
# Speed: 2.3ms preprocess, 1616.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 racquet s, 760.4ms
# Speed: 2.5ms preprocess, 760.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1674.7ms
# Speed: 0.0ms preprocess, 1674.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 racquet , 769.3ms
# Speed: 4.0ms preprocess, 769.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1650.6ms
# Speed: 8.0ms preprocess, 1650.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 racquet , 782.5ms
# Speed: 0.0ms preprocess, 782.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1676.8ms
# Speed: 1.7ms preprocess, 1676.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 racquet s, 783.0ms
# Speed: 2.2ms preprocess, 783.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1731.2ms
# Speed: 6.8ms preprocess, 1731.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 racquet s, 755.4ms
# Speed: 3.4ms preprocess, 755.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1625.4ms
# Speed: 2.6ms preprocess, 1625.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 racquet s, 761.0ms
# Speed: 0.0ms preprocess, 761.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1644.4ms
# Speed: 2.4ms preprocess, 1644.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 racquet s, 762.8ms
# Speed: 1.2ms preprocess, 762.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1630.6ms
# Speed: 5.3ms preprocess, 1630.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 racquet , 758.9ms
# Speed: 2.3ms preprocess, 758.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1619.9ms
# Speed: 2.2ms preprocess, 1619.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 racquet , 758.4ms
# Speed: 4.4ms preprocess, 758.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1625.9ms
# Speed: 3.0ms preprocess, 1625.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 racquet s, 764.2ms
# Speed: 7.6ms preprocess, 764.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1639.3ms
# Speed: 3.4ms preprocess, 1639.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 racquet , 765.3ms
# Speed: 2.3ms preprocess, 765.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# Processed video 5.mp4 saved to: D:\DDSA\Serve Pose Detection\Output video\5_output_video.mp4
# Analysis data saved to: D:\DDSA\Serve Pose Detection\Output video\5_analysis_20251004_133046.csv
# Maximum Ball Height: 827.93 cm
# Maximum Wrist Arc Curvature: 61.18 deg
# Maximum Angular Velocity: 1516.54 deg/s
# Service Motion Time: 0.033 s
#
# All videos processed successfully!
